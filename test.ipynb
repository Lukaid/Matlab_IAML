# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

iris = pd.read_csv('iris.csv')

# %%
iris['variety'][90]
# Out:
# 'Versicolor'

# %%
X_1 = iris['sepal.length'][0:100]
X_2 = iris['sepal.width'][0:100]
X = pd.concat([X_1, X_2], axis=1)
X
# Out:
#     sepal.length  sepal.width
# 0            5.1          3.5
# 1            4.9          3.0
# 2            4.7          3.2
# 3            4.6          3.1
# 4            5.0          3.6
# ..           ...          ...
# 95           5.7          3.0
# 96           5.7          2.9
# 97           6.2          2.9
# 98           5.1          2.5
# 99           5.7          2.8
#
# [100 rows x 2 columns]

# %%
Y = iris['variety'][0:100]
for i in range(0, 100):
    if Y[i] == 'Setosa':
        Y[i] = 1
    else:
        Y[i] = -1

Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 95    -1
# 96    -1
# 97    -1
# 98    -1
# 99    -1
# Name: variety, Length: 100, dtype: object

# %%
# Out:
# -1

# %%
plt.scatter(X['sepal.length'][0:50], X['sepal.width'][0:50], label = 'Setosa')
plt.scatter(X['sepal.length'][50:100], X['sepal.width'][50:100], label = 'Versicolor')
plt.xlabel('sepal.length')
plt.ylabel('sepal.width')
plt.legend()
plt.show()

# %%
def step_f(z):
    if z >= 0:
        return 1
    else:
        return -1

# %%
n_iter = 10
eta = 0.1
w = [0, 0, 0]

print(w)
# Out:
# [0, 0, 0]

# %%
Yhat = []

for j in range(n_iter):
    for i in range(len(X)):
        Yhat.append(step_f(np.dot(w, [1] + list(X.loc[i]))))

        for k in range(0, 3):
            w[k] = w[k] + eta*(Y[i] - Yhat[i])*([1] + list(X.loc[i]))[k]

# %%
w
# Out:
# [-1.9999999999999998, -14.000000000000002, -6.400000000000002]

# %%
x_1 = list(np.arange(4, 7, 0.1))
x_2 = []

for h in range(len(x_1)):
    x_2.append( -w[0]/w[2] -(w[1]/w[2])*x_1[h])


plt.plot(x_1, x_2)
plt.show()



#for h in range(len())

# %%
([1] + list(X.loc[0]))[2]
# Out:
# 3.5

# %%
np.dot(w, [1] + list(X.loc[0]))
# Out:
# 0.0

# %%
[1] + list(X.loc[0])
# Out:
# [1, 5.1, 3.5]

# %%
print([1]+list(X.loc[0]))
# Out:
# [1, 5.1, 3.5]
